# %% [markdown]
# # LSTM

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.offline import iplot
from keras.layers import Dropout
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from mergen import StringAnalyzer, StringProfiling
# %load_ext autotime
# Out:
# time: 0 ns (started: 2023-04-05 19:58:15 +03:00)

# %%
data = pd.read_csv("teknofest_train_final.csv", sep="|", encoding="utf-8")
data = data[['text','target']]
data = StringAnalyzer(data=data, columns='text').dataframe_analyze()
data.head()
# Out:
#                                                 text     target
# 0                                        çürük dişli     INSULT
# 1  adamın islama müslümanlara verdiği zararı gavu...     RACIST
# 2                               erkekler zora gelmez     SEXIST
# 3  utanmazın götüne kazık sokmuşlar tıkırtı geliy...  PROFANITY
# 4       otomasyon sistemlerine doğrudan bağlanabilir      OTHER
# time: 4.2 s (started: 2023-04-05 19:58:15 +03:00)

# %%
# The maximum number of words to be used. (most frequent)
MAX_NB_WORDS = 20000
# Max number of words in each complaint.
MAX_SEQUENCE_LENGTH = 25
# This is fixed.
EMBEDDING_DIM = 100

tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(data['text'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 23981 unique tokens.
# time: 625 ms (started: 2023-04-05 19:58:19 +03:00)

# %%
X = tokenizer.texts_to_sequences(data['text'].values)
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', X.shape)
# Out:
# Shape of data tensor: (12617, 25)
# time: 532 ms (started: 2023-04-05 19:58:19 +03:00)

# %%
Y = pd.get_dummies(data['target']).values
print('Shape of label tensor:', Y.shape)
# Out:
# Shape of label tensor: (12617, 5)
# time: 16 ms (started: 2023-04-05 19:58:20 +03:00)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.10, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (11355, 25) (11355, 5)
# (1262, 25) (1262, 5)
# time: 15 ms (started: 2023-04-05 19:58:20 +03:00)

# %%
model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(5, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 25, 100)           2000000
#
#  spatial_dropout1d (SpatialD  (None, 25, 100)          0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 100)               80400
#
#  dense (Dense)               (None, 5)                 505
#
# =================================================================
# Total params: 2,080,905
# Trainable params: 2,080,905
# Non-trainable params: 0
# _________________________________________________________________
# None
# time: 782 ms (started: 2023-04-05 19:58:20 +03:00)

# %%
epochs = 5
batch_size = 256

history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
# Out:
# Epoch 1/5
# 40/40 [==============================] - 24s 399ms/step - loss: 1.5662 - accuracy: 0.2936 - val_loss: 1.4896 - val_accuracy: 0.4445
# Epoch 2/5
# 40/40 [==============================] - 16s 399ms/step - loss: 1.2135 - accuracy: 0.5524 - val_loss: 0.9546 - val_accuracy: 0.6769
# Epoch 3/5
# 40/40 [==============================] - 13s 332ms/step - loss: 0.5823 - accuracy: 0.8184 - val_loss: 0.6581 - val_accuracy: 0.7676
# Epoch 4/5
# 40/40 [==============================] - 9s 221ms/step - loss: 0.3007 - accuracy: 0.9131 - val_loss: 0.5739 - val_accuracy: 0.7975
# Epoch 5/5
# 40/40 [==============================] - 9s 222ms/step - loss: 0.1794 - accuracy: 0.9491 - val_loss: 0.5590 - val_accuracy: 0.8072
# time: 1min 10s (started: 2023-04-05 19:58:21 +03:00)

# %%
accr = model.evaluate(X_test,Y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 40/40 [==============================] - 1s 23ms/step - loss: 0.5548 - accuracy: 0.8201
# Test set
#   Loss: 0.555
#   Accuracy: 0.820
# time: 1.05 s (started: 2023-04-05 19:59:32 +03:00)

# %%
from sklearn.metrics import precision_recall_fscore_support

Y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_test, axis=1)

# F1, precision ve recall değerlerini hesapla
f1, precision, recall, _ = precision_recall_fscore_support(Y_true, Y_pred_classes, average='weighted')

print("F1 Score: ", f1)
print("Precision Score: ", precision)
print("Recall Score: ", recall)
# Out:
# 40/40 [==============================] - 2s 35ms/step
# F1 Score:  0.8337662837190921
# Precision Score:  0.8201267828843106
# Recall Score:  0.8233771424535437
# time: 2.31 s (started: 2023-04-05 19:59:33 +03:00)

# %%
from sklearn.metrics import confusion_matrix

# modelin tahminleri
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

# gerçek sınıflar
y_true = np.argmax(Y_test, axis=1)

# confusion matrix
cm = confusion_matrix(y_true, y_pred)

# confusion matrix grafiği
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 40/40 [==============================] - 1s 19ms/step
# time: 1.55 s (started: 2023-04-05 19:59:35 +03:00)

# %%
from sklearn.metrics import classification_report

# Sınıflandırma etiketlerini tahmin et
Y_pred = model.predict(X_test)

# En yüksek olasılığa sahip sınıf etiketlerini seç
Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_test, axis=1)

# Sınıf bazında doğruluk, hassasiyet ve F1 skorlarını hesapla
report = classification_report(Y_true, Y_pred_classes, target_names=['INSULT', 'RACIST', 'SEXIST', 'PROFANITY', 'OTHER'], output_dict=True)

# Bar grafiği oluştur
fig, ax = plt.subplots(figsize=(10, 6))
class_names = list(report.keys())[:-3] # Son üç satır hassasiyet, doğruluk ve F1 Skoru toplamları olduğundan bunları çıkardık
metrics = ['precision', 'recall', 'f1-score']
for i, metric in enumerate(metrics):
    ax.bar([j+(i*0.8/3) for j in range(1, len(class_names)+1)], [report[class_name][metric] for class_name in class_names], width=0.8/3, label=metric)
ax.set_xticks(range(1, len(class_names)+1))
ax.set_xticklabels(class_names)
ax.set_ylim([0, 1])
ax.legend()
plt.show()
# Out:
# 40/40 [==============================] - 1s 20ms/step
# time: 1.42 s (started: 2023-04-05 19:59:37 +03:00)

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();
# Out:
# time: 422 ms (started: 2023-04-05 19:59:38 +03:00)

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show();
# Out:
# time: 453 ms (started: 2023-04-05 19:59:39 +03:00)

# %%
#model.save("tf_model.h5")
# Out:
# time: 0 ns (started: 2023-04-05 19:59:39 +03:00)
